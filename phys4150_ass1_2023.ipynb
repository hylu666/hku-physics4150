# %%
import numpy as np
import matplotlib.pyplot as plt
import copy

# %% [markdown]
# ## Comet's Revolution

# %% [markdown]
# <font  face=Times color=darkblue size=3> For the revolution due to the gravitational fore $\vec F=\frac{-GMm}{r^2}\hat r\ $, the equation of motion is: $\frac{d^2\vec r}{dt^2}=-\frac{\mu}{r^3}\vec r$, where $\mu=G(M+m)$. We can write this in two directions and get two differential equations: $\ddot{r}-r\dot{\theta}^2=-\frac{GM}{r^2}$ and $r\ddot{\theta}+2\dot{r}\dot{\theta}=0$.
#     <br>Now we denote $u=\frac{1}{r}$, now the angular velocity is: $$\dot{\theta}=\frac{l}{mr^2}=\frac{lu^2}{m},\  {\rm where}\ \ l\ \ {\rm is\ the\ angular\ momentum}. $$ And there is a differential relationship: $$\frac{d}{dt}=\dot{\theta}\frac{d}{d\theta}=\frac{lu^2}{m}\frac{d}{d\theta}.$$ So that, $$\dot{r}=\frac{lu^2}{m}\frac{d}{d\theta}\frac{1}{u}=-\frac{l}{m}\frac{du}{d\theta}, \ \ \ddot{r}=\frac{lu^2}{m}\frac{d\dot{r}}{d\theta}=-\frac{l^2u^2}{m^2}\frac{du^2}{d\theta^2}.$$ Take these into $\ddot{r}-r\dot{\theta}^2=-\frac{GM}{r^2}$: $$\frac{d^2u}{d\theta^2}+u=\frac{GMm^2}{l^2}. $$ To solve this, we first list a particular solution $u=\frac{GMm^2}{l^2}$, and then solve $\frac{d^2u}{d\theta^2}+u=0$, and get $u=C\cos{\theta-\theta_0}$, where $C$ and $\theta_0$ are constants. Therefore, the general solution is: $$\frac{1}{r}=\frac{GMm^2}{l^2}(1+e\cos{\theta}).$$ $e$ is the eccentricity and it is an equation for conic section, which is the content of Kepler's 1st law.
#     <br><br> To prove Kepler's 2nd law, we have: $$\dot{\vec r}=\dot{r}\hat{r}+r\dot{\theta}\hat{\theta},\ \ \ddot{\vec r}=(\ddot{r}-r\dot{\theta}^2)\hat{r}+(r\ddot{\theta}+2\dot{r}\dot{\theta})\hat{\theta}. $$ Combine it with $\ddot{\vec r}=-G\frac{M}{r^2}\hat r$, then get: $$\ddot{r}-r\dot{\theta}^2=-G\frac{M}{r^2},\ \ \ r\ddot{\theta}+2\dot{r}\dot{\theta}=0.$$ As $l=mr^2\dot{\theta}$ and the mass of the moon is a constant: $$\dot{l}=mr(r\ddot{\theta}+2\dot{r}\dot{\theta})=0.$$ The areas that the line joining the moon and the Earth sweeps is: $$\Delta A=\int_{t_1}^{t_2}=\frac{1}{2}\cdot r\cdot r\dot{\theta}\cdot dt=\int_{t_1}^{t_2}\frac{l}{2m}dt.$$ Since we have proved the angular momentum is constant, the areas of equal time are also constants, which supports the 2nd law.
#     <br><br>We already know that the moon moves in an ellipse aroung the Earth, and now we can test the methods introduced before to numerically solve the differential equations and plot the trajectory to see the performance of the methods (here we consider the best Runge-Kutta method, the velocity Verlet method and the worst Euler method.). Moreover, we use the numerical results to prove the Kepler's 2nd law.
#     <br><br>
#     The initial condition is: $x=a(1-e)$, $y=0$, $v_x=0$, $v_y=\sqrt{\mu(1+e)/[a(1-e)]}$. We take $\mu=G(M+m)$, semi-major axis $a=1.00$, and eccentricity $e=0.0549$. We take the unit of $t$ to be 1 day.

# %%
G = 6.6743 * 10**-11;
# notie that here unit is (m^3 kg^-1 s^-2) 
# which is in 国际标准单位

#in our given basis, time unit = 1 day 
time_unit = 365*24*60*60 #second
#length unit 3.84748 × 10^8  m
AU = 149597871*10**3
length_unit = 17.8*AU #meter
#mass unit 5.972 × 1024 kg
mass_unit = 1.98892*10**30 #kg

# therefore, we renormalize the G
G_new = G / (length_unit**3) * (mass_unit**1) * (time_unit**2)

# %%
e = 0.967
a = 1
M = 1
m = 2.2*10**14/mass_unit
mu = G_new*(M+m)

initial_x = a*(1-e)
initial_vy = np.sqrt(mu*(1+e)/(a*(1-e)))

# %%
initial_x,initial_vy
# Out:
# (0.03300000000000003, 0.645572784379443)

# %%
mu
# Out:
# 0.006991977253552158

# %% [markdown]
# ### Euler Method

# %% [markdown]
# with $\tau=0.05,0.1,0.5$

# %%
tau=0.00001
x_eu=[initial_x]
y_eu=[0]
vx_eu=[0]
vy_eu=[initial_vy]
t_eu=[0]

# %%
for i in range(1,int(75/tau)):
    t_eu.append(tau*i)
    x_eu.append(x_eu[i-1]+tau*vx_eu[i-1])
    ax_here= (-mu/np.power((x_eu[i-1]**2+y_eu[i-1]**2),1.5))*x_eu[i-1]
    vx_eu.append(vx_eu[i-1]+tau*ax_here)
    y_eu.append(y_eu[i-1]+tau*vy_eu[i-1])
    ay_here= (-mu/np.power((x_eu[i-1]**2+y_eu[i-1]**2),1.5))*y_eu[i-1]
    vy_eu.append(vy_eu[i-1]+tau*ay_here)

# %%
tau=0.1
x_eu1=[initial_x]
y_eu1=[0]
vx_eu1=[0]
vy_eu1=[initial_vy]
t_eu1=[0]

# %%
for i in range(1,800):
    t_eu1.append(tau*i)
    x_eu1.append(x_eu1[i-1]+tau*vx_eu1[i-1])
    ax_here= (-mu/np.power((x_eu1[i-1]**2+y_eu1[i-1]**2),1.5))*x_eu1[i-1]
    vx_eu1.append(vx_eu1[i-1]+tau*ax_here)
    y_eu1.append(y_eu1[i-1]+tau*vy_eu1[i-1])
    ay_here= (-mu/np.power((x_eu1[i-1]**2+y_eu1[i-1]**2),1.5))*y_eu1[i-1]
    vy_eu1.append(vy_eu1[i-1]+tau*ay_here)

# %%
tau=0.5
x_eu2=[initial_x]
y_eu2=[0]
vx_eu2=[0]
vy_eu2=[initial_vy]
t_eu2=[0]

# %%
for i in range(1,150):
    t_eu2.append(tau*i)
    x_eu2.append(x_eu2[i-1]+tau*vx_eu2[i-1])
    ax_here= (-mu/np.power((x_eu2[i-1]**2+y_eu2[i-1]**2),1.5))*x_eu2[i-1]
    vx_eu2.append(vx_eu2[i-1]+tau*ax_here)
    y_eu2.append(y_eu2[i-1]+tau*vy_eu2[i-1])
    ay_here= (-mu/np.power((x_eu2[i-1]**2+y_eu2[i-1]**2),1.5))*y_eu2[i-1]
    vy_eu2.append(vy_eu2[i-1]+tau*ay_here)

# %%
plt.figure(figsize=(6,6))
#plt.plot(x_eu2,y_eu2,'-',label=r'Euler $\tau=0.5$')
#plt.plot(x_eu1,y_eu1,'--',label=r'Euler $\tau=0.1$')
plt.plot(x_eu,y_eu,'-.',label=r'Euler $\tau=0.05$')

plt.legend()
plt.xlabel('x')
plt.ylabel('y')
# Out:
# Text(0, 0.5, 'y')

# %% [markdown]
# <font  face=Times color=darkblue size=3> We have simulated 3 values of $\tau$ and totally 30 days, and again see that that the error of Euler method increases with time and the larger the time-step, the larger the error.

# %% [markdown]
# ### Velocity Verlet Method

# %% [markdown]
# with $\tau = 0.1,1,2$

# %%
tau=0.01
x_vv_tauP1=[initial_x]
y_vv_tauP1=[0]
vx_vv_tauP1=[0]
vy_vv_tauP1=[initial_vy]
t_vv_tauP1=[0]

# %%
for i in range(1,int(76/tau)):
    t_vv_tauP1.append(tau*i)
    ax_vv = (-mu/np.power((x_vv_tauP1[i-1]**2+y_vv_tauP1[i-1]**2),1.5))*x_vv_tauP1[i-1]
    ay_vv = (-mu/np.power((x_vv_tauP1[i-1]**2+y_vv_tauP1[i-1]**2),1.5))*y_vv_tauP1[i-1]
    x_vv_tauP1.append(x_vv_tauP1[i-1]+tau*vx_vv_tauP1[i-1]+0.5*np.power(tau,2)*ax_vv)
    y_vv_tauP1.append(y_vv_tauP1[i-1]+tau*vy_vv_tauP1[i-1]+0.5*np.power(tau,2)*ay_vv)
    ax_vvi = (-mu/np.power((x_vv_tauP1[i]**2+y_vv_tauP1[i]**2),1.5))*x_vv_tauP1[i]
    ay_vvi = (-mu/np.power((x_vv_tauP1[i]**2+y_vv_tauP1[i]**2),1.5))*y_vv_tauP1[i]
    vx_vv_tauP1.append(vx_vv_tauP1[i-1]+0.5*tau*(ax_vv+ax_vvi))
    vy_vv_tauP1.append(vy_vv_tauP1[i-1]+0.5*tau*(ay_vv+ay_vvi))

# %%
tau=1
x_vv_tau1=[initial_x]
y_vv_tau1=[0]
vx_vv_tau1=[0]
vy_vv_tau1=[initial_vy]
t_vv_tau1=[0]
for i in range(1,30):
    t_vv_tau1.append(tau*i)
    ax_vv = (-mu/np.power((x_vv_tau1[i-1]**2+y_vv_tau1[i-1]**2),1.5))*x_vv_tau1[i-1]
    ay_vv = (-mu/np.power((x_vv_tau1[i-1]**2+y_vv_tau1[i-1]**2),1.5))*y_vv_tau1[i-1]
    x_vv_tau1.append(x_vv_tau1[i-1]+tau*vx_vv_tau1[i-1]+0.5*np.power(tau,2)*ax_vv)
    y_vv_tau1.append(y_vv_tau1[i-1]+tau*vy_vv_tau1[i-1]+0.5*np.power(tau,2)*ay_vv)
    ax_vvi = (-mu/np.power((x_vv_tau1[i]**2+y_vv_tau1[i]**2),1.5))*x_vv_tau1[i]
    ay_vvi = (-mu/np.power((x_vv_tau1[i]**2+y_vv_tau1[i]**2),1.5))*y_vv_tau1[i]
    vx_vv_tau1.append(vx_vv_tau1[i-1]+0.5*tau*(ax_vv+ax_vvi))
    vy_vv_tau1.append(vy_vv_tau1[i-1]+0.5*tau*(ay_vv+ay_vvi))

# %%
tau=2
x_vv_tau4=[initial_x]
y_vv_tau4=[0]
vx_vv_tau4=[0]
vy_vv_tau4=[initial_vy]
t_vv_tau4=[0]
for i in range(1,15):
    t_vv_tau4.append(tau*i)
    ax_vv = (-mu/np.power((x_vv_tau4[i-1]**2+y_vv_tau4[i-1]**2),1.5))*x_vv_tau4[i-1]
    ay_vv = (-mu/np.power((x_vv_tau4[i-1]**2+y_vv_tau4[i-1]**2),1.5))*y_vv_tau4[i-1]
    x_vv_tau4.append(x_vv_tau4[i-1]+tau*vx_vv_tau4[i-1]+0.5*np.power(tau,2)*ax_vv)
    y_vv_tau4.append(y_vv_tau4[i-1]+tau*vy_vv_tau4[i-1]+0.5*np.power(tau,2)*ay_vv)
    ax_vvi = (-mu/np.power((x_vv_tau4[i]**2+y_vv_tau4[i]**2),1.5))*x_vv_tau4[i]
    ay_vvi = (-mu/np.power((x_vv_tau4[i]**2+y_vv_tau4[i]**2),1.5))*y_vv_tau4[i]
    vx_vv_tau4.append(vx_vv_tau4[i-1]+0.5*tau*(ax_vv+ax_vvi))
    vy_vv_tau4.append(vy_vv_tau4[i-1]+0.5*tau*(ay_vv+ay_vvi))

# %%
plt.figure(figsize=(6,6))
plt.plot(x_vv_tauP1,y_vv_tauP1,'--',label=r'Velocity Verlet $\tau=0.1$')
#plt.plot(x_vv_tau1,y_vv_tau1,'-.',label=r'Velocity Verlet $\tau=1$')
#plt.plot(x_vv_tau4,y_vv_tau4,'-',label=r'Velocity Verlet $\tau=2$')
#plt.scatter(x_vv_tauP1,y_vv_tauP1)
#plt.scatter(x_vv_tau1,y_vv_tau1)
#plt.scatter(x_vv_tau4,y_vv_tau4)

plt.legend()
plt.xlabel('x')
plt.ylabel('y')
# Out:
# Text(0, 0.5, 'y')

# %% [markdown]
# ### 4-th Order Runge-Kutta Method

# %% [markdown]
# with $\tau=0.5,1,3$

# %%
tau=0.01
x_rk=[initial_x]
y_rk=[0]
vx_rk=[0]
vy_rk=[initial_vy]
t_rk=[0]

# %%
for i in range(1,int(77/tau)):
    t_rk.append(tau*i)
    k1x=tau*vx_rk[i-1]
    k1y=tau*vy_rk[i-1]
    ax_here1= (-mu/np.power((x_rk[i-1]**2+y_rk[i-1]**2),1.5))*x_rk[i-1]
    ay_here1= (-mu/np.power((x_rk[i-1]**2+y_rk[i-1]**2),1.5))*y_rk[i-1]
    l1x=tau*ax_here1
    l1y=tau*ay_here1
    k2x=tau*(vx_rk[i-1]+0.5*l1x)
    k2y=tau*(vy_rk[i-1]+0.5*l1y)
    ax_here2= (-mu/np.power(((x_rk[i-1]+0.5*k1x)**2+(y_rk[i-1]+0.5*k1y)**2),1.5))*(x_rk[i-1]+0.5*k1x)
    ay_here2= (-mu/np.power(((x_rk[i-1]+0.5*k1x)**2+(y_rk[i-1]+0.5*k1y)**2),1.5))*(y_rk[i-1]+0.5*k1y)
    l2x=tau*ax_here2
    l2y=tau*ay_here2
    k3x=tau*(vx_rk[i-1]+0.5*l2x)
    k3y=tau*(vy_rk[i-1]+0.5*l2y)
    ax_here3= (-mu/np.power(((x_rk[i-1]+0.5*k2x)**2+(y_rk[i-1]+0.5*k2y)**2),1.5))*(x_rk[i-1]+0.5*k2x)
    ay_here3= (-mu/np.power(((x_rk[i-1]+0.5*k2x)**2+(y_rk[i-1]+0.5*k2y)**2),1.5))*(y_rk[i-1]+0.5*k2y)
    l3x=tau*ax_here3
    l3y=tau*ay_here3
    k4x=tau*(vx_rk[i-1]+l3x)
    k4y=tau*(vy_rk[i-1]+l3y)
    ax_here4= (-mu/np.power(((x_rk[i-1]+k3x)**2+(y_rk[i-1]+k3y)**2),1.5))*(x_rk[i-1]+k3x)
    ay_here4= (-mu/np.power(((x_rk[i-1]+k3x)**2+(y_rk[i-1]+k3y)**2),1.5))*(y_rk[i-1]+k3y)
    l4x=tau*ax_here4
    l4y=tau*ay_here4
    x_rk.append(x_rk[i-1]+(1/6)*(k1x+2*k2x+2*k3x+k4x))
    vx_rk.append(vx_rk[i-1]+(1/6)*(l1x+2*l2x+2*l3x+l4x))
    y_rk.append(y_rk[i-1]+(1/6)*(k1y+2*k2y+2*k3y+k4y))
    vy_rk.append(vy_rk[i-1]+(1/6)*(l1y+2*l2y+2*l3y+l4y))

# %%
xrk_40=copy.deepcopy(x_rk)
yrk_40=copy.deepcopy(y_rk)

# %%
tau=0.5
x_rk=[initial_x]
y_rk=[0]
vx_rk=[0]
vy_rk=[initial_vy]
t_rk=[0]

# %%
for i in range(1,60):
    t_rk.append(tau*i)
    k1x=tau*vx_rk[i-1]
    k1y=tau*vy_rk[i-1]
    ax_here1= (-mu/np.power((x_rk[i-1]**2+y_rk[i-1]**2),1.5))*x_rk[i-1]
    ay_here1= (-mu/np.power((x_rk[i-1]**2+y_rk[i-1]**2),1.5))*y_rk[i-1]
    l1x=tau*ax_here1
    l1y=tau*ay_here1
    k2x=tau*(vx_rk[i-1]+0.5*l1x)
    k2y=tau*(vy_rk[i-1]+0.5*l1y)
    ax_here2= (-mu/np.power(((x_rk[i-1]+0.5*k1x)**2+(y_rk[i-1]+0.5*k1y)**2),1.5))*(x_rk[i-1]+0.5*k1x)
    ay_here2= (-mu/np.power(((x_rk[i-1]+0.5*k1x)**2+(y_rk[i-1]+0.5*k1y)**2),1.5))*(y_rk[i-1]+0.5*k1y)
    l2x=tau*ax_here2
    l2y=tau*ay_here2
    k3x=tau*(vx_rk[i-1]+0.5*l2x)
    k3y=tau*(vy_rk[i-1]+0.5*l2y)
    ax_here3= (-mu/np.power(((x_rk[i-1]+0.5*k2x)**2+(y_rk[i-1]+0.5*k2y)**2),1.5))*(x_rk[i-1]+0.5*k2x)
    ay_here3= (-mu/np.power(((x_rk[i-1]+0.5*k2x)**2+(y_rk[i-1]+0.5*k2y)**2),1.5))*(y_rk[i-1]+0.5*k2y)
    l3x=tau*ax_here3
    l3y=tau*ay_here3
    k4x=tau*(vx_rk[i-1]+l3x)
    k4y=tau*(vy_rk[i-1]+l3y)
    ax_here4= (-mu/np.power(((x_rk[i-1]+k3x)**2+(y_rk[i-1]+k3y)**2),1.5))*(x_rk[i-1]+k3x)
    ay_here4= (-mu/np.power(((x_rk[i-1]+k3x)**2+(y_rk[i-1]+k3y)**2),1.5))*(y_rk[i-1]+k3y)
    l4x=tau*ax_here4
    l4y=tau*ay_here4
    x_rk.append(x_rk[i-1]+(1/6)*(k1x+2*k2x+2*k3x+k4x))
    vx_rk.append(vx_rk[i-1]+(1/6)*(l1x+2*l2x+2*l3x+l4x))
    y_rk.append(y_rk[i-1]+(1/6)*(k1y+2*k2y+2*k3y+k4y))
    vy_rk.append(vy_rk[i-1]+(1/6)*(l1y+2*l2y+2*l3y+l4y))

# %%
xrk_4=copy.deepcopy(x_rk)
yrk_4=copy.deepcopy(y_rk)

# %%
tau=1
x_rk=[initial_x]
y_rk=[0]
vx_rk=[0]
vy_rk=[initial_vy]
t_rk=[0]

# %%
for i in range(1,30):
    t_rk.append(tau*i)
    k1x=tau*vx_rk[i-1]
    k1y=tau*vy_rk[i-1]
    ax_here1= (-mu/np.power((x_rk[i-1]**2+y_rk[i-1]**2),1.5))*x_rk[i-1]
    ay_here1= (-mu/np.power((x_rk[i-1]**2+y_rk[i-1]**2),1.5))*y_rk[i-1]
    l1x=tau*ax_here1
    l1y=tau*ay_here1
    k2x=tau*(vx_rk[i-1]+0.5*l1x)
    k2y=tau*(vy_rk[i-1]+0.5*l1y)
    ax_here2= (-mu/np.power(((x_rk[i-1]+0.5*k1x)**2+(y_rk[i-1]+0.5*k1y)**2),1.5))*(x_rk[i-1]+0.5*k1x)
    ay_here2= (-mu/np.power(((x_rk[i-1]+0.5*k1x)**2+(y_rk[i-1]+0.5*k1y)**2),1.5))*(y_rk[i-1]+0.5*k1y)
    l2x=tau*ax_here2
    l2y=tau*ay_here2
    k3x=tau*(vx_rk[i-1]+0.5*l2x)
    k3y=tau*(vy_rk[i-1]+0.5*l2y)
    ax_here3= (-mu/np.power(((x_rk[i-1]+0.5*k2x)**2+(y_rk[i-1]+0.5*k2y)**2),1.5))*(x_rk[i-1]+0.5*k2x)
    ay_here3= (-mu/np.power(((x_rk[i-1]+0.5*k2x)**2+(y_rk[i-1]+0.5*k2y)**2),1.5))*(y_rk[i-1]+0.5*k2y)
    l3x=tau*ax_here3
    l3y=tau*ay_here3
    k4x=tau*(vx_rk[i-1]+l3x)
    k4y=tau*(vy_rk[i-1]+l3y)
    ax_here4= (-mu/np.power(((x_rk[i-1]+k3x)**2+(y_rk[i-1]+k3y)**2),1.5))*(x_rk[i-1]+k3x)
    ay_here4= (-mu/np.power(((x_rk[i-1]+k3x)**2+(y_rk[i-1]+k3y)**2),1.5))*(y_rk[i-1]+k3y)
    l4x=tau*ax_here4
    l4y=tau*ay_here4
    x_rk.append(x_rk[i-1]+(1/6)*(k1x+2*k2x+2*k3x+k4x))
    vx_rk.append(vx_rk[i-1]+(1/6)*(l1x+2*l2x+2*l3x+l4x))
    y_rk.append(y_rk[i-1]+(1/6)*(k1y+2*k2y+2*k3y+k4y))
    vy_rk.append(vy_rk[i-1]+(1/6)*(l1y+2*l2y+2*l3y+l4y))

# %%
xrk_20=copy.deepcopy(x_rk)
yrk_20=copy.deepcopy(y_rk)

# %%
time_point = np.argmax((np.array(vx_rk[len(vx_rk)//2:])**2 + np.array(vy_rk[len(vx_rk)//2:])**2))

# %%
(time_point+len(vx_rk)//2)*tau
# Out:
# 15

# %%
len(vx_rk)
# Out:
# 30

# %%
plt.figure(figsize=(6,6))
#plt.plot(xrk_4,yrk_4,'--',label=r'Runge-Kutta $\tau=0.5$')
#plt.plot(xrk_20,yrk_20,'-.',label=r'Runge-Kutta $\tau=1$')
plt.plot(xrk_40,yrk_40,label=r'Runge-Kutta $\tau=3$')
plt.plot(xrk_40[0],yrk_40[0],"ro")
plt.plot(xrk_40[-1],yrk_40[-1],"bo")

plt.legend()

plt.axis('equal')

plt.xlabel('x')
plt.ylabel('y')
# Out:
# Text(0, 0.5, 'y')

# %% [markdown]
# <font  face=Times color=darkblue size=3> We see that for this method, the error will not increase with time but with the time-step.

# %% [markdown]
# ### Comparison

# %%
plt.figure(figsize=(9,9))
plt.plot(x_eu2,y_eu2,'-',label=r'Euler $\tau=0.5$')
plt.plot(x_eu1,y_eu1,'--',label=r'Euler $\tau=0.1$')
plt.plot(x_eu,y_eu,'-.',label=r'Euler $\tau=0.05$')


plt.plot(x_vv_tauP1,y_vv_tauP1,'--',label=r'Velocity Verlet $\tau=0.1$')
plt.plot(x_vv_tau1,y_vv_tau1,'-.',label=r'Velocity Verlet $\tau=1$')
plt.plot(x_vv_tau4,y_vv_tau4,'-',label=r'Velocity Verlet $\tau=2$')

plt.plot(xrk_4,yrk_4,'--',label=r'Runge-Kutta $\tau=0.5$')

plt.scatter([a*(1-e)],[0],color='black',label='pericenter')
plt.scatter([-a*(1+e)],[0],color='gray',label='Apocenter')
plt.scatter([0],[0],color='darkred',label='Earth',marker='*')
plt.xlim(-1.5,1.5)
plt.ylim(-1.5,1.5)
plt.legend()
plt.xlabel('x')
plt.ylabel('y')
# Out:
# Text(0, 0.5, 'y')

# %%
E_eu=1/2*(np.square(vx_eu)+np.square(vy_eu))-mu*np.power(np.square(x_eu)+np.square(y_eu),-1/2)
E_vv=1/2*(np.square(vx_vv_tau1)+np.square(vy_vv_tau1))-mu*np.power(np.square(x_vv_tau1)+np.square(y_vv_tau1),-1/2)
E_rk=1/2*(np.square(vx_rk)+np.square(vy_rk))-mu*np.power(np.square(x_rk)+np.square(y_rk),-1/2)

# %%
plt.plot(np.multiply(0.05,list(range(600))),E_eu,'--',label=r'Euler $\tau=0.05$')
plt.plot(np.multiply(1,list(range(30))),E_vv,'--',label=r'Velocity Verlet $\tau=1$')
plt.plot(np.multiply(1,list(range(30))),E_rk,'--',label=r'RK4 $\tau=1$')
plt.legend()
plt.xlabel('t')
plt.ylabel('E')
# Out:
# Text(0, 0.5, 'E')

# %%
plt.plot(np.multiply(1,list(range(30))),E_vv,'--',label=r'Velocity Verlet $\tau=1$')
plt.plot(np.multiply(1,list(range(30))),E_rk,'--',label=r'RK4 $\tau=1$')
plt.legend()
plt.xlabel('t')
plt.ylabel('E')
# Out:
# Text(0, 0.5, 'E')

# %% [markdown]
# <font  face=Times color=darkblue size=3> We can see that Runge-Kutta method is the best and the Euler method is the worst.

# %% [markdown]
# ### Kepler's 2nd law

# %% [markdown]
# <font  face=Times color=darkblue size=3> We use Runge-Kutta results to compute the areas swept within equal time. Forget that the angular momentum is constant and the integral of the area can be discretely written as $$\sum_{t_1}^{t_2}\frac{l}{2m}dt,$$ for our numerical method $dt$ is 1 day and $m$ is constant. So we can diretly compute the sum of $\frac{l}{m}=vr$ within equal time to check the 2nd law.

# %%
mu
# Out:
# 0.05288507585906535

# %%
tau=0.5
x_rk=[initial_x]
y_rk=[0]
vx_rk=[0]
vy_rk=[initial_vy]
t_rk=[0]
for i in range(1,60):
    t_rk.append(tau*i)
    k1x=tau*vx_rk[i-1]
    k1y=tau*vy_rk[i-1]
    ax_here1= (-mu/np.power((x_rk[i-1]**2+y_rk[i-1]**2),1.5))*x_rk[i-1]
    ay_here1= (-mu/np.power((x_rk[i-1]**2+y_rk[i-1]**2),1.5))*y_rk[i-1]
    l1x=tau*ax_here1
    l1y=tau*ay_here1
    k2x=tau*(vx_rk[i-1]+0.5*l1x)
    k2y=tau*(vy_rk[i-1]+0.5*l1y)
    ax_here2= (-mu/np.power(((x_rk[i-1]+0.5*k1x)**2+(y_rk[i-1]+0.5*k1y)**2),1.5))*(x_rk[i-1]+0.5*k1x)
    ay_here2= (-mu/np.power(((x_rk[i-1]+0.5*k1x)**2+(y_rk[i-1]+0.5*k1y)**2),1.5))*(y_rk[i-1]+0.5*k1y)
    l2x=tau*ax_here2
    l2y=tau*ay_here2
    k3x=tau*(vx_rk[i-1]+0.5*l2x)
    k3y=tau*(vy_rk[i-1]+0.5*l2y)
    ax_here3= (-mu/np.power(((x_rk[i-1]+0.5*k2x)**2+(y_rk[i-1]+0.5*k2y)**2),1.5))*(x_rk[i-1]+0.5*k2x)
    ay_here3= (-mu/np.power(((x_rk[i-1]+0.5*k2x)**2+(y_rk[i-1]+0.5*k2y)**2),1.5))*(y_rk[i-1]+0.5*k2y)
    l3x=tau*ax_here3
    l3y=tau*ay_here3
    k4x=tau*(vx_rk[i-1]+l3x)
    k4y=tau*(vy_rk[i-1]+l3y)
    ax_here4= (-mu/np.power(((x_rk[i-1]+k3x)**2+(y_rk[i-1]+k3y)**2),1.5))*(x_rk[i-1]+k3x)
    ay_here4= (-mu/np.power(((x_rk[i-1]+k3x)**2+(y_rk[i-1]+k3y)**2),1.5))*(y_rk[i-1]+k3y)
    l4x=tau*ax_here4
    l4y=tau*ay_here4
    
    x_rk.append(x_rk[i-1]+(1/6)*(k1x+2*k2x+2*k3x+k4x))
    vx_rk.append(vx_rk[i-1]+(1/6)*(l1x+2*l2x+2*l3x+l4x))
    y_rk.append(y_rk[i-1]+(1/6)*(k1y+2*k2y+2*k3y+k4y))
    vy_rk.append(vy_rk[i-1]+(1/6)*(l1y+2*l2y+2*l3y+l4y))

# %%
# for example, we examine by taking a period of 1 days.
list_of_5period=[]
start_time=range(0,60,2)

for j in start_time:
    sum_here=0
    for i in range(j,j+2):
        sum_here+=np.sqrt(vx_rk[i]**2+vy_rk[i]**2)*np.sqrt(x_rk[i]**2+y_rk[i]**2) #v*r
    list_of_5period.append(sum_here)

# %%
list_of_5period
# Out:
# [0.45924655739380255,
#  0.45930561921571267,
#  0.459429543311262,
#  0.4595887322143703,
#  0.4597463930762816,
#  0.4598678127410873,
#  0.4599281422221666,
#  0.4599169324421356,
#  0.4598389517485557,
#  0.4597118378663085,
#  0.4595616609785576,
#  0.459417562663067,
#  0.45930646859761937,
#  0.4592486163060806,
#  0.45925439067436863,
#  0.45932275573186465,
#  0.4594414094235265,
#  0.45958864931886756,
#  0.4597367961163158,
#  0.45985685359556866,
#  0.4599238709113107,
#  0.4599222190049055,
#  0.4598497430263496,
#  0.45971961753865787,
#  0.45955888480107526,
#  0.45940327080925725,
#  0.45928897088535314,
#  0.45924338014634714,
#  0.4592775908164447,
#  0.45938325014074477]

# %%
max(list_of_5period)-min(list_of_5period)
# Out:
# 0.0006847620758194672

# %%
plt.plot(range(len(list_of_5period)),list_of_5period)
